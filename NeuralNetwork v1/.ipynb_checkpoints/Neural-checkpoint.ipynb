# %% [markdown]
# Here we will just check the effiency against an optimized and universal library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List

# %%
raw_df = pd.read_csv('sevenfive.csv')
test_df = pd.read_csv('sevenfiveVALIDATION.csv')

# %%
sns.scatterplot(data=raw_df.sample(100), x='x1', y='x2', hue='report');

# %%
inputs_df = raw_df[['x1','x2']]
targets_df = raw_df[['report']]
test_inputs_df = test_df[['x1','x2']]
test_targets_df = test_df[['report']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(inputs_df)
# Out:
# StandardScaler()

# %%
inputs_df = scaler.transform(inputs_df)
test_inputs_df = scaler.transform(test_inputs_df)

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier(random_state=42, max_depth=2, max_leaf_nodes = 3)
model.fit(inputs_df, targets_df)
# Out:
# DecisionTreeClassifier(max_depth=2, max_leaf_nodes=3, random_state=42)

# %%
print(model.score(inputs_df, targets_df), model.score(test_inputs_df, test_targets_df))
# Out:
# 1.0 0.999

# %%
singleinput = scaler.transform([[7,5]])
# Out:
# E:\USER\miniconda3\envs\tf\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
model.predict(singleinput+0.01)
# Out:
# array([1], dtype=int64)

# %%
tree.plot_tree(model);

# %%
def NodeCost(outputActivation: float, expectedOutput: float) -> float:
    return (outputActivation - expectedOutput) ** 2

# %%
def Cost(predicted: List, expected: List) -> float:
    assert len(predicted) == len(expected), "The outputs must be the same length"
    price = []
    for i in range(len(predicted)):
        price.append(NodeCost(predicted[i], expected[i]))
    return np.mean(price)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(2,)),
    keras.layers.Dense(4, activation='sigmoid'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
custom_optimizer = keras.optimizers.Adam(learning_rate=0.001)  # Cambia el valor de learning_rate según lo que desees
model.compile(optimizer=custom_optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Imprimir un resumen del modelo
model.summary()

# Los datos de entrada (x1 y x2) y las etiquetas (Veredicto) deben estar en arrays NumPy
# Asumiendo que tienes tus datos en variables x_train (entradas) y y_train (etiquetas), puedes entrenar el modelo de la siguiente manera:
model.fit(inputs_df, targets_df, epochs=50, batch_size=1)

# Una vez entrenado, puedes usar el modelo para hacer predicciones
predictions = model.predict(inputs_df)  # x_test contiene tus datos de prueba

# Las predicciones estarán en el rango de 0 a 1, puedes convertirlas a 0 o 1 usando un umbral:
threshold = 0.75
binary_predictions = (predictions > threshold).astype(int)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 12
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 9s 3ms/step - loss: 0.7007 - accuracy: 0.4640
# Epoch 2/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6049 - accuracy: 0.6740
# Epoch 3/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.5367 - accuracy: 0.7580
# Epoch 4/50
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4893 - accuracy: 0.7790
# Epoch 5/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4610 - accuracy: 0.7800
# Epoch 6/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4455 - accuracy: 0.7840
# Epoch 7/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4360 - accuracy: 0.7890
# Epoch 8/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4297 - accuracy: 0.7900
# Epoch 9/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4243 - accuracy: 0.7930
# Epoch 10/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4188 - accuracy: 0.7910
# Epoch 11/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4131 - accuracy: 0.7950
# Epoch 12/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4067 - accuracy: 0.8010
# Epoch 13/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3994 - accuracy: 0.8020
# Epoch 14/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3915 - accuracy: 0.8040
# Epoch 15/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3832 - accuracy: 0.8100
# Epoch 16/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3739 - accuracy: 0.8220
# Epoch 17/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3642 - accuracy: 0.8300
# Epoch 18/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3541 - accuracy: 0.8410
# Epoch 19/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3433 - accuracy: 0.8510
# Epoch 20/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3323 - accuracy: 0.8590
# Epoch 21/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3211 - accuracy: 0.8670
# Epoch 22/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3100 - accuracy: 0.8850
# Epoch 23/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2990 - accuracy: 0.8950
# Epoch 24/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2879 - accuracy: 0.9050
# Epoch 25/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2775 - accuracy: 0.9160
# Epoch 26/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2668 - accuracy: 0.9200
# Epoch 27/50
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2566 - accuracy: 0.9260
# Epoch 28/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2465 - accuracy: 0.9300
# Epoch 29/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.2371 - accuracy: 0.9380
# Epoch 30/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2280 - accuracy: 0.9420
# Epoch 31/50
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2196 - accuracy: 0.9450
# Epoch 32/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.2114 - accuracy: 0.9480
# Epoch 33/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2036 - accuracy: 0.9490
# Epoch 34/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1966 - accuracy: 0.9540
# Epoch 35/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1897 - accuracy: 0.9520
# Epoch 36/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1830 - accuracy: 0.9560
# Epoch 37/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1773 - accuracy: 0.9570
# Epoch 38/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1717 - accuracy: 0.9620
# Epoch 39/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1662 - accuracy: 0.9620
# Epoch 40/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1611 - accuracy: 0.9620
# Epoch 41/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1565 - accuracy: 0.9660
# Epoch 42/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1521 - accuracy: 0.9680
# Epoch 43/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1479 - accuracy: 0.9670
# Epoch 44/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1441 - accuracy: 0.9700
# Epoch 45/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1404 - accuracy: 0.9690
# Epoch 46/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1369 - accuracy: 0.9710
# Epoch 47/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1338 - accuracy: 0.9670
# Epoch 48/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1307 - accuracy: 0.9700
# Epoch 49/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1280 - accuracy: 0.9700
# Epoch 50/50
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1250 - accuracy: 0.9690
# 32/32 [==============================] - 0s 2ms/step

# %%
predictions = model.predict(inputs_df)  # x_test contiene tus datos de prueba

# Las predicciones estarán en el rango de 0 a 1, puedes convertirlas a 0 o 1 usando un umbral:
threshold = 0.5
binary_predictions = (predictions > threshold).astype(int)
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
Cost(binary_predictions, targets_df.to_numpy())
# Out:
# 0.029

# %%
predictions = model.predict(test_inputs_df)  # x_test contiene tus datos de prueba

# Las predicciones estarán en el rango de 0 a 1, puedes convertirlas a 0 o 1 usando un umbral:
threshold = 0.5
binary_predictions = (predictions > threshold).astype(int)
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
Cost(binary_predictions, test_targets_df.to_numpy())
# Out:
# 0.032

# %%
model.predict(singleinput+0.2)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# array([[0.52287877]], dtype=float32)

# %%
singleinput
# Out:
# array([[-0.50450496, -0.6801852 ]])
